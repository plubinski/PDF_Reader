# %%
import os

# %% [markdown]
# # Colab path

# %%
try:
  import google.colab
  IN_COLAB = True
except:
  IN_COLAB = False

if IN_COLAB == True:
  path = '/content/drive/My Drive/Colab Notebooks/DWRZ/PDF Reader'
  os.chdir(path)
  print('GOOGLE DRIVE: ', os.getcwd())
else:
  print('LOCAL DRIVE: ', os.getcwd())
# Out:
# GOOGLE DRIVE:  /content/drive/My Drive/Colab Notebooks/DWRZ/PDF Reader

# %%
# !ls
# Out:
# input  pdf_reader.ipynb

# %%
# !ls input
# Out:
# hebe.pdf  rossmann.pdf

# %% [markdown]
# # PyPDF2

# %%
# !pip3 install PyPDF2
# Out:
# ...
#      |████████████████████████████████| 81kB 2.5MB/s
# ...
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-cp36-none-any.whl size=61086 sha256=d7ad2a5f0ba1a706bd1a42465617388ca49ab93af7ab0b163ebbaa49757b6c86
#   Stored in directory: /root/.cache/pip/wheels/53/84/19/35bc977c8bf5f0c23a8a011aa958acd4da4bbd7a229315c1b7
# Successfully built PyPDF2
# ...

# %%
import PyPDF2

# %%
def pdf_reader(filename):
  pdfFileObject = open(filename,  'rb')
  pdfReader = PyPDF2.PdfFileReader(pdfFileObject)
  info = pdfReader.getDocumentInfo()
  count = pdfReader.numPages

  print('Informacje o pliku PDF: ', info, '\n')
  print('Odczytałem stron: ', count, '\n\n')

  for i in range(count):
      page = pdfReader.getPage(i)
      print('===== STRONA ', i, '==== \n')
      print(page.extractText())

# %%
pdf_reader('input/rossmann.pdf')
# Out:
# Informacje o pliku PDF:  {'/ModDate': "D:20200331141756+02'00'", '/CreationDate': "D:20200331141756+02'00'", '/Producer': 'iText 2.1.7 by 1T3XT'}
#
# Odczytałem stron:  18
#
#
# ===== STRONA  0 ====
#
# 1Œ24 kwietnia 2020
#
# ===== STRONA  1 ====
#
# Promocja trwa 1Œ24.04.2020 lub do wyczerpania zapasów
# Wella, Wellaton,
# krem intensywnie
# koloryzuj˛cy, 4/0
# ˝redni br˛z, 1 szt.
# 14,49
# 9,99
# 1 szt. = 9.99 z˜
# L™Oréal Paris,
# Récital Préférence,
# farba do w˜osów,
# ch˜odne re˙eksy,
# Z2 10.21 Stockholm,
# bardzo jasny blond
# opalizuj˛cy, 1 szt.
# 33,99
# 24,99
# 1 szt. = 24.99 z˜
# Isana, Style 2 Create,
# krem matuj˛cy, 100 ml
# Taˆ, Volume,
# supermocny lakier
# do w˜osów, 250 ml
# 13
# ,79
# 9,99
# 100 ml = 4.00 z˜
# Gliss Kur,
# Supreme Length,
# ekspresowa
# odˇywka
# regeneracyjna do
# w˜osów, 200 ml
# 12
# ,99
# 9,29
# 100 ml = 4.65 z˜
# Herbal Essences,
# bio:renew,
# odˇywka do
# w˜osów, naprawa
# i wyg˜adzenie, 275
# ml19,99
# 14,99
# 100 ml = 5.45 z˜
# ...

# %% [markdown]
# # TIKA

# %%
# !pip install tika
# Out:
# ...
#   Created wheel for tika: filename=tika-1.24-cp36-none-any.whl size=32885 sha256=f7e009ef82e7408fcef686aebd970a64a6016772246133876206e530adad1313
#   Stored in directory: /root/.cache/pip/wheels/73/9c/f5/0b1b738442fc2a2862bef95b908b374f8e80215550fb2a8975
# Successfully built tika
# ...

# %%
from tika import parser

# %%
def pdf_reader_2(filename):  
  rawText = parser.from_file(filename)
  rawList = rawText['content'].splitlines()
  print('Odczytalem: \n')
  print(rawList)

# %%
pdf_reader_2('input/rossmann.pdf')
# Out:
# Odczytalem:
#
# ...
